# %%
import numpy as np
import pandas as pd

# %%
import pickle

# Load the dataframe from the pickle file
with open('vectorized_data.pkl', 'rb') as f:
    df_vectorized = pickle.load(f)

# Verify the data
print(df_vectorized.head())
# Out:
#                                                 text  Number of Words  \
# 0  [-0.5290401, 1.3665133, -0.80768013, -0.391093...             71.0
# 1  [-0.27918544, 0.26646057, -2.0142102, 0.874655...             35.0
# 2  [-0.85621387, 0.5165809, -1.5286032, 0.0605149...            115.0
# 3  [-0.2679573, 1.6229212, -0.97719175, 0.5954116...             71.0
# 4  [-1.3925172, 1.2192382, -1.3127025, 0.8323619,...             55.0
#
#    Number of Unique Words  Lexical Diversity  label                    labels
# 0                    57.0           1.245614     10          rec.sport.hockey
# 1                    29.0           1.206897      3  comp.sys.ibm.pc.hardware
# 2                    93.0           1.236559     17     talk.politics.mideast
# 3                    40.0           1.775000      3  comp.sys.ibm.pc.hardware
# 4                    40.0           1.375000      4     comp.sys.mac.hardware

# %%
# Create a DataFrame from the 300-dimensional text vector
text_vectors = np.stack(df_vectorized['text'])
text_df = pd.DataFrame(text_vectors, columns=[f'text_feature_{i}' for i in range(1,301)])

# %%
text_df
# Out:
#        text_feature_1  text_feature_2  text_feature_3  text_feature_4  \
# 0           -0.529040        1.366513       -0.807680       -0.391093
# 1           -0.279185        0.266461       -2.014210        0.874655
# 2           -0.856214        0.516581       -1.528603        0.060515
# 3           -0.267957        1.622921       -0.977192        0.595412
# 4           -1.392517        1.219238       -1.312703        0.832362
# ...               ...             ...             ...             ...
# 18841        0.081482        1.300209       -1.430490        0.081386
# 18842       -1.123459        0.402567       -1.458515        2.001488
# 18843       -0.806958        2.226107       -2.340649        2.700698
# 18844        0.245300        2.751035       -1.687650       -0.209340
# 18845       -0.186047        0.466077       -1.676920        0.044679
#
#        text_feature_5  text_feature_6  text_feature_7  text_feature_8  \
# 0            0.556891        0.331544        1.807316        2.714442
# 1            2.001537       -0.535391        1.380789        2.109462
# 2            2.280041        0.532967        1.277382        2.651986
# 3            2.160348        0.218418        0.638600        3.136519
# 4            1.833941        0.253066        1.250301        3.711750
# ...               ...             ...             ...             ...
# 18841        1.254414       -0.732815        1.323335        3.150269
# 18842        2.275669       -2.466568        2.533670        3.563533
# 18843        1.503375        0.837379        1.849937        5.135254
# 18844        2.579864        1.104067        1.084535        3.142964
# 18845        1.421358        0.167642        0.928038        2.595414
#
#        text_feature_9  text_feature_10  ...  text_feature_291  \
# 0           -2.612218        -0.075514  ...          1.684348
# 1           -3.023489        -0.260620  ...          0.487771
# 2           -1.052777         0.310467  ...          1.784927
# 3           -2.452479        -0.193923  ...          0.115210
# 4           -3.129509         0.801260  ...          0.938145
# ...               ...              ...  ...               ...
# 18841       -2.189784         0.580509  ...          1.451453
# 18842       -2.491650         0.706272  ...          0.498268
# 18843       -2.180741         0.305510  ...          0.196345
# 18844       -2.297940         0.830064  ...          0.710421
# 18845       -1.819425         0.857033  ...          0.674561
#
#        text_feature_292  text_feature_293  text_feature_294  text_feature_295  \
# 0             -1.129226          1.550328          0.157012         -1.369549
# 1              0.064291          0.144577          0.208926         -1.064808
# 2             -0.473679          0.256193         -0.448327         -1.533778
# 3              0.138336          0.126363          0.529545         -0.029485
# 4             -0.355510          0.904905         -0.021950         -0.325176
# ...                 ...               ...               ...               ...
# 18841         -1.023552          2.305305         -1.023903         -1.194132
# 18842          0.276353          2.204401         -2.118853         -2.320965
# 18843          1.132956         -0.046711          0.186622         -0.777530
# 18844         -0.843718          1.702891         -0.886655         -0.886455
# 18845         -0.425264          0.313798         -0.324806         -1.448064
#
#        text_feature_296  text_feature_297  text_feature_298  text_feature_299  \
# 0             -0.233906          1.018852          0.300667         -1.962461
# 1              0.246307          0.807237         -1.064619         -1.719875
# 2             -0.039482          0.784111          0.309479         -1.090555
# 3              2.168380         -0.827677         -3.357024         -0.045534
# 4             -0.583913         -0.526114         -0.833042         -1.447465
# ...                 ...               ...               ...               ...
# 18841         -0.242372          0.574178         -1.041952         -2.033468
# 18842          0.844922          0.988037         -2.280889         -2.498724
# 18843          2.187178          0.490825         -1.289197         -2.039326
# 18844          0.063011         -0.246446         -0.130195         -2.599871
# 18845         -0.194501          0.564039         -0.683131         -0.994453
#
#        text_feature_300
# 0              0.290608
# 1              0.743530
# 2              1.068606
# 3              1.829613
# 4              1.027189
# ...                 ...
# 18841          1.528738
# 18842          0.377307
# 18843          1.422640
# 18844          1.165472
# 18845          0.782340
#
# [18846 rows x 300 columns]

# %%
df_combined = pd.concat([df_vectorized.reset_index(drop=True), text_df], axis=1)

# %%
df_combined.drop(columns=['text'], inplace=True)

# %%
df_combined
# Out:
#        Number of Words  Number of Unique Words  Lexical Diversity  label  \
# 0                 71.0                    57.0           1.245614     10
# 1                 35.0                    29.0           1.206897      3
# 2                115.0                    93.0           1.236559     17
# 3                 71.0                    40.0           1.775000      3
# 4                 55.0                    40.0           1.375000      4
# ...                ...                     ...                ...    ...
# 18841            165.0                   120.0           1.375000     13
# 18842             18.0                    17.0           1.058824     12
# 18843             50.0                    36.0           1.388889      3
# 18844             25.0                    21.0           1.190476      1
# 18845            128.0                   107.0           1.196262      7
#
#                          labels  text_feature_1  text_feature_2  \
# 0              rec.sport.hockey       -0.529040        1.366513
# 1      comp.sys.ibm.pc.hardware       -0.279185        0.266461
# 2         talk.politics.mideast       -0.856214        0.516581
# 3      comp.sys.ibm.pc.hardware       -0.267957        1.622921
# 4         comp.sys.mac.hardware       -1.392517        1.219238
# ...                         ...             ...             ...
# 18841                   sci.med        0.081482        1.300209
# 18842           sci.electronics       -1.123459        0.402567
# 18843  comp.sys.ibm.pc.hardware       -0.806958        2.226107
# 18844             comp.graphics        0.245300        2.751035
# 18845                 rec.autos       -0.186047        0.466077
#
#        text_feature_3  text_feature_4  text_feature_5  ...  text_feature_291  \
# 0           -0.807680       -0.391093        0.556891  ...          1.684348
# 1           -2.014210        0.874655        2.001537  ...          0.487771
# 2           -1.528603        0.060515        2.280041  ...          1.784927
# 3           -0.977192        0.595412        2.160348  ...          0.115210
# 4           -1.312703        0.832362        1.833941  ...          0.938145
# ...               ...             ...             ...  ...               ...
# 18841       -1.430490        0.081386        1.254414  ...          1.451453
# 18842       -1.458515        2.001488        2.275669  ...          0.498268
# 18843       -2.340649        2.700698        1.503375  ...          0.196345
# 18844       -1.687650       -0.209340        2.579864  ...          0.710421
# 18845       -1.676920        0.044679        1.421358  ...          0.674561
#
#        text_feature_292  text_feature_293  text_feature_294  text_feature_295  \
# 0             -1.129226          1.550328          0.157012         -1.369549
# 1              0.064291          0.144577          0.208926         -1.064808
# 2             -0.473679          0.256193         -0.448327         -1.533778
# 3              0.138336          0.126363          0.529545         -0.029485
# 4             -0.355510          0.904905         -0.021950         -0.325176
# ...                 ...               ...               ...               ...
# 18841         -1.023552          2.305305         -1.023903         -1.194132
# 18842          0.276353          2.204401         -2.118853         -2.320965
# 18843          1.132956         -0.046711          0.186622         -0.777530
# 18844         -0.843718          1.702891         -0.886655         -0.886455
# 18845         -0.425264          0.313798         -0.324806         -1.448064
#
#        text_feature_296  text_feature_297  text_feature_298  text_feature_299  \
# 0             -0.233906          1.018852          0.300667         -1.962461
# 1              0.246307          0.807237         -1.064619         -1.719875
# 2             -0.039482          0.784111          0.309479         -1.090555
# 3              2.168380         -0.827677         -3.357024         -0.045534
# 4             -0.583913         -0.526114         -0.833042         -1.447465
# ...                 ...               ...               ...               ...
# 18841         -0.242372          0.574178         -1.041952         -2.033468
# 18842          0.844922          0.988037         -2.280889         -2.498724
# 18843          2.187178          0.490825         -1.289197         -2.039326
# 18844          0.063011         -0.246446         -0.130195         -2.599871
# 18845         -0.194501          0.564039         -0.683131         -0.994453
#
#        text_feature_300
# 0              0.290608
# 1              0.743530
# 2              1.068606
# 3              1.829613
# 4              1.027189
# ...                 ...
# 18841          1.528738
# 18842          0.377307
# 18843          1.422640
# 18844          1.165472
# 18845          0.782340
#
# [18846 rows x 305 columns]

# %%
df_vectorized.columns
# Out:
# Index(['text', 'Number of Words', 'Number of Unique Words',
#        'Lexical Diversity', 'label', 'labels'],
#       dtype='object')

# %%
df_combined = df_combined[list(text_df.columns)+['Number of Words', 'Number of Unique Words',
       'Lexical Diversity', 'label', 'labels']]

# %%
df_combined
# Out:
#        text_feature_1  text_feature_2  text_feature_3  text_feature_4  \
# 0           -0.529040        1.366513       -0.807680       -0.391093
# 1           -0.279185        0.266461       -2.014210        0.874655
# 2           -0.856214        0.516581       -1.528603        0.060515
# 3           -0.267957        1.622921       -0.977192        0.595412
# 4           -1.392517        1.219238       -1.312703        0.832362
# ...               ...             ...             ...             ...
# 18841        0.081482        1.300209       -1.430490        0.081386
# 18842       -1.123459        0.402567       -1.458515        2.001488
# 18843       -0.806958        2.226107       -2.340649        2.700698
# 18844        0.245300        2.751035       -1.687650       -0.209340
# 18845       -0.186047        0.466077       -1.676920        0.044679
#
#        text_feature_5  text_feature_6  text_feature_7  text_feature_8  \
# 0            0.556891        0.331544        1.807316        2.714442
# 1            2.001537       -0.535391        1.380789        2.109462
# 2            2.280041        0.532967        1.277382        2.651986
# 3            2.160348        0.218418        0.638600        3.136519
# 4            1.833941        0.253066        1.250301        3.711750
# ...               ...             ...             ...             ...
# 18841        1.254414       -0.732815        1.323335        3.150269
# 18842        2.275669       -2.466568        2.533670        3.563533
# 18843        1.503375        0.837379        1.849937        5.135254
# 18844        2.579864        1.104067        1.084535        3.142964
# 18845        1.421358        0.167642        0.928038        2.595414
#
#        text_feature_9  text_feature_10  ...  text_feature_296  \
# 0           -2.612218        -0.075514  ...         -0.233906
# 1           -3.023489        -0.260620  ...          0.246307
# 2           -1.052777         0.310467  ...         -0.039482
# 3           -2.452479        -0.193923  ...          2.168380
# 4           -3.129509         0.801260  ...         -0.583913
# ...               ...              ...  ...               ...
# 18841       -2.189784         0.580509  ...         -0.242372
# 18842       -2.491650         0.706272  ...          0.844922
# 18843       -2.180741         0.305510  ...          2.187178
# 18844       -2.297940         0.830064  ...          0.063011
# 18845       -1.819425         0.857033  ...         -0.194501
#
#        text_feature_297  text_feature_298  text_feature_299  text_feature_300  \
# 0              1.018852          0.300667         -1.962461          0.290608
# 1              0.807237         -1.064619         -1.719875          0.743530
# 2              0.784111          0.309479         -1.090555          1.068606
# 3             -0.827677         -3.357024         -0.045534          1.829613
# 4             -0.526114         -0.833042         -1.447465          1.027189
# ...                 ...               ...               ...               ...
# 18841          0.574178         -1.041952         -2.033468          1.528738
# 18842          0.988037         -2.280889         -2.498724          0.377307
# 18843          0.490825         -1.289197         -2.039326          1.422640
# 18844         -0.246446         -0.130195         -2.599871          1.165472
# 18845          0.564039         -0.683131         -0.994453          0.782340
#
#        Number of Words  Number of Unique Words  Lexical Diversity  label  \
# 0                 71.0                    57.0           1.245614     10
# 1                 35.0                    29.0           1.206897      3
# 2                115.0                    93.0           1.236559     17
# 3                 71.0                    40.0           1.775000      3
# 4                 55.0                    40.0           1.375000      4
# ...                ...                     ...                ...    ...
# 18841            165.0                   120.0           1.375000     13
# 18842             18.0                    17.0           1.058824     12
# 18843             50.0                    36.0           1.388889      3
# 18844             25.0                    21.0           1.190476      1
# 18845            128.0                   107.0           1.196262      7
#
#                          labels
# 0              rec.sport.hockey
# 1      comp.sys.ibm.pc.hardware
# 2         talk.politics.mideast
# 3      comp.sys.ibm.pc.hardware
# 4         comp.sys.mac.hardware
# ...                         ...
# 18841                   sci.med
# 18842           sci.electronics
# 18843  comp.sys.ibm.pc.hardware
# 18844             comp.graphics
# 18845                 rec.autos
#
# [18846 rows x 305 columns]

# %%
df_combined.shape
# Out:
# (18846, 305)

# %%
X=df_combined.drop(["label","labels"],axis=1)

# %%
X
# Out:
#        text_feature_1  text_feature_2  text_feature_3  text_feature_4  \
# 0           -0.529040        1.366513       -0.807680       -0.391093
# 1           -0.279185        0.266461       -2.014210        0.874655
# 2           -0.856214        0.516581       -1.528603        0.060515
# 3           -0.267957        1.622921       -0.977192        0.595412
# 4           -1.392517        1.219238       -1.312703        0.832362
# ...               ...             ...             ...             ...
# 18841        0.081482        1.300209       -1.430490        0.081386
# 18842       -1.123459        0.402567       -1.458515        2.001488
# 18843       -0.806958        2.226107       -2.340649        2.700698
# 18844        0.245300        2.751035       -1.687650       -0.209340
# 18845       -0.186047        0.466077       -1.676920        0.044679
#
#        text_feature_5  text_feature_6  text_feature_7  text_feature_8  \
# 0            0.556891        0.331544        1.807316        2.714442
# 1            2.001537       -0.535391        1.380789        2.109462
# 2            2.280041        0.532967        1.277382        2.651986
# 3            2.160348        0.218418        0.638600        3.136519
# 4            1.833941        0.253066        1.250301        3.711750
# ...               ...             ...             ...             ...
# 18841        1.254414       -0.732815        1.323335        3.150269
# 18842        2.275669       -2.466568        2.533670        3.563533
# 18843        1.503375        0.837379        1.849937        5.135254
# 18844        2.579864        1.104067        1.084535        3.142964
# 18845        1.421358        0.167642        0.928038        2.595414
#
#        text_feature_9  text_feature_10  ...  text_feature_294  \
# 0           -2.612218        -0.075514  ...          0.157012
# 1           -3.023489        -0.260620  ...          0.208926
# 2           -1.052777         0.310467  ...         -0.448327
# 3           -2.452479        -0.193923  ...          0.529545
# 4           -3.129509         0.801260  ...         -0.021950
# ...               ...              ...  ...               ...
# 18841       -2.189784         0.580509  ...         -1.023903
# 18842       -2.491650         0.706272  ...         -2.118853
# 18843       -2.180741         0.305510  ...          0.186622
# 18844       -2.297940         0.830064  ...         -0.886655
# 18845       -1.819425         0.857033  ...         -0.324806
#
#        text_feature_295  text_feature_296  text_feature_297  text_feature_298  \
# 0             -1.369549         -0.233906          1.018852          0.300667
# 1             -1.064808          0.246307          0.807237         -1.064619
# 2             -1.533778         -0.039482          0.784111          0.309479
# 3             -0.029485          2.168380         -0.827677         -3.357024
# 4             -0.325176         -0.583913         -0.526114         -0.833042
# ...                 ...               ...               ...               ...
# 18841         -1.194132         -0.242372          0.574178         -1.041952
# 18842         -2.320965          0.844922          0.988037         -2.280889
# 18843         -0.777530          2.187178          0.490825         -1.289197
# 18844         -0.886455          0.063011         -0.246446         -0.130195
# 18845         -1.448064         -0.194501          0.564039         -0.683131
#
#        text_feature_299  text_feature_300  Number of Words  \
# 0             -1.962461          0.290608             71.0
# 1             -1.719875          0.743530             35.0
# 2             -1.090555          1.068606            115.0
# 3             -0.045534          1.829613             71.0
# 4             -1.447465          1.027189             55.0
# ...                 ...               ...              ...
# 18841         -2.033468          1.528738            165.0
# 18842         -2.498724          0.377307             18.0
# 18843         -2.039326          1.422640             50.0
# 18844         -2.599871          1.165472             25.0
# 18845         -0.994453          0.782340            128.0
#
#        Number of Unique Words  Lexical Diversity
# 0                        57.0           1.245614
# 1                        29.0           1.206897
# 2                        93.0           1.236559
# 3                        40.0           1.775000
# 4                        40.0           1.375000
# ...                       ...                ...
# 18841                   120.0           1.375000
# 18842                    17.0           1.058824
# 18843                    36.0           1.388889
# 18844                    21.0           1.190476
# 18845                   107.0           1.196262
#
# [18846 rows x 303 columns]

# %%
X.shape
# Out:
# (18846, 303)

# %%
import torch as tr

# %%
ytrue= tr.tensor(df_combined.label)

# %%
ytrue.shape
# Out:
# torch.Size([18846])

# %%
feature_names=X.columns

# %%
feature_names_=list(feature_names)

# %%
feature_names_
# Out:
# ['text_feature_1',
#  'text_feature_2',
#  'text_feature_3',
#  'text_feature_4',
#  'text_feature_5',
#  'text_feature_6',
#  'text_feature_7',
#  'text_feature_8',
#  'text_feature_9',
#  'text_feature_10',
#  'text_feature_11',
#  'text_feature_12',
#  'text_feature_13',
#  'text_feature_14',
#  'text_feature_15',
#  'text_feature_16',
#  'text_feature_17',
#  'text_feature_18',
#  'text_feature_19',
#  'text_feature_20',
#  'text_feature_21',
#  'text_feature_22',
#  'text_feature_23',
#  'text_feature_24',
#  'text_feature_25',
#  'text_feature_26',
#  'text_feature_27',
#  'text_feature_28',
#  'text_feature_29',
#  'text_feature_30',
#  'text_feature_31',
#  'text_feature_32',
#  'text_feature_33',
#  'text_feature_34',
#  'text_feature_35',
#  'text_feature_36',
#  'text_feature_37',
#  'text_feature_38',
#  'text_feature_39',
#  'text_feature_40',
#  'text_feature_41',
#  'text_feature_42',
#  'text_feature_43',
#  'text_feature_44',
#  'text_feature_45',
#  'text_feature_46',
#  'text_feature_47',
#  'text_feature_48',
#  'text_feature_49',
#  'text_feature_50',
#  'text_feature_51',
#  'text_feature_52',
#  'text_feature_53',
#  'text_feature_54',
#  'text_feature_55',
#  'text_feature_56',
#  'text_feature_57',
#  'text_feature_58',
#  'text_feature_59',
#  'text_feature_60',
#  'text_feature_61',
#  'text_feature_62',
#  'text_feature_63',
#  'text_feature_64',
#  'text_feature_65',
#  'text_feature_66',
#  'text_feature_67',
#  'text_feature_68',
#  'text_feature_69',
#  'text_feature_70',
#  'text_feature_71',
#  'text_feature_72',
#  'text_feature_73',
#  'text_feature_74',
#  'text_feature_75',
#  'text_feature_76',
#  'text_feature_77',
#  'text_feature_78',
#  'text_feature_79',
#  'text_feature_80',
#  'text_feature_81',
#  'text_feature_82',
#  'text_feature_83',
#  'text_feature_84',
#  'text_feature_85',
#  'text_feature_86',
#  'text_feature_87',
#  'text_feature_88',
#  'text_feature_89',
#  'text_feature_90',
#  'text_feature_91',
#  'text_feature_92',
#  'text_feature_93',
#  'text_feature_94',
#  'text_feature_95',
#  'text_feature_96',
#  'text_feature_97',
#  'text_feature_98',
#  'text_feature_99',
#  'text_feature_100',
#  'text_feature_101',
#  'text_feature_102',
#  'text_feature_103',
#  'text_feature_104',
#  'text_feature_105',
#  'text_feature_106',
#  'text_feature_107',
#  'text_feature_108',
#  'text_feature_109',
#  'text_feature_110',
#  'text_feature_111',
#  'text_feature_112',
#  'text_feature_113',
#  'text_feature_114',
#  'text_feature_115',
#  'text_feature_116',
#  'text_feature_117',
#  'text_feature_118',
#  'text_feature_119',
#  'text_feature_120',
#  'text_feature_121',
#  'text_feature_122',
#  'text_feature_123',
#  'text_feature_124',
#  'text_feature_125',
#  'text_feature_126',
#  'text_feature_127',
#  'text_feature_128',
#  'text_feature_129',
#  'text_feature_130',
#  'text_feature_131',
#  'text_feature_132',
#  'text_feature_133',
#  'text_feature_134',
#  'text_feature_135',
#  'text_feature_136',
#  'text_feature_137',
#  'text_feature_138',
#  'text_feature_139',
#  'text_feature_140',
#  'text_feature_141',
#  'text_feature_142',
#  'text_feature_143',
#  'text_feature_144',
#  'text_feature_145',
#  'text_feature_146',
#  'text_feature_147',
#  'text_feature_148',
#  'text_feature_149',
#  'text_feature_150',
#  'text_feature_151',
#  'text_feature_152',
#  'text_feature_153',
#  'text_feature_154',
#  'text_feature_155',
#  'text_feature_156',
#  'text_feature_157',
#  'text_feature_158',
#  'text_feature_159',
#  'text_feature_160',
#  'text_feature_161',
#  'text_feature_162',
#  'text_feature_163',
#  'text_feature_164',
#  'text_feature_165',
#  'text_feature_166',
#  'text_feature_167',
#  'text_feature_168',
#  'text_feature_169',
#  'text_feature_170',
#  'text_feature_171',
#  'text_feature_172',
#  'text_feature_173',
#  'text_feature_174',
#  'text_feature_175',
#  'text_feature_176',
#  'text_feature_177',
#  'text_feature_178',
#  'text_feature_179',
#  'text_feature_180',
#  'text_feature_181',
#  'text_feature_182',
#  'text_feature_183',
#  'text_feature_184',
#  'text_feature_185',
#  'text_feature_186',
#  'text_feature_187',
#  'text_feature_188',
#  'text_feature_189',
#  'text_feature_190',
#  'text_feature_191',
#  'text_feature_192',
#  'text_feature_193',
#  'text_feature_194',
#  'text_feature_195',
#  'text_feature_196',
#  'text_feature_197',
#  'text_feature_198',
#  'text_feature_199',
#  'text_feature_200',
#  'text_feature_201',
#  'text_feature_202',
#  'text_feature_203',
#  'text_feature_204',
#  'text_feature_205',
#  'text_feature_206',
#  'text_feature_207',
#  'text_feature_208',
#  'text_feature_209',
#  'text_feature_210',
#  'text_feature_211',
#  'text_feature_212',
#  'text_feature_213',
#  'text_feature_214',
#  'text_feature_215',
#  'text_feature_216',
#  'text_feature_217',
#  'text_feature_218',
#  'text_feature_219',
#  'text_feature_220',
#  'text_feature_221',
#  'text_feature_222',
#  'text_feature_223',
#  'text_feature_224',
#  'text_feature_225',
#  'text_feature_226',
#  'text_feature_227',
#  'text_feature_228',
#  'text_feature_229',
#  'text_feature_230',
#  'text_feature_231',
#  'text_feature_232',
#  'text_feature_233',
#  'text_feature_234',
#  'text_feature_235',
#  'text_feature_236',
#  'text_feature_237',
#  'text_feature_238',
#  'text_feature_239',
#  'text_feature_240',
#  'text_feature_241',
#  'text_feature_242',
#  'text_feature_243',
#  'text_feature_244',
#  'text_feature_245',
#  'text_feature_246',
#  'text_feature_247',
#  'text_feature_248',
#  'text_feature_249',
#  'text_feature_250',
#  'text_feature_251',
#  'text_feature_252',
#  'text_feature_253',
#  'text_feature_254',
#  'text_feature_255',
#  'text_feature_256',
#  'text_feature_257',
#  'text_feature_258',
#  'text_feature_259',
#  'text_feature_260',
#  'text_feature_261',
#  'text_feature_262',
#  'text_feature_263',
#  'text_feature_264',
#  'text_feature_265',
#  'text_feature_266',
#  'text_feature_267',
#  'text_feature_268',
#  'text_feature_269',
#  'text_feature_270',
#  'text_feature_271',
#  'text_feature_272',
#  'text_feature_273',
#  'text_feature_274',
#  'text_feature_275',
#  'text_feature_276',
#  'text_feature_277',
#  'text_feature_278',
#  'text_feature_279',
#  'text_feature_280',
#  'text_feature_281',
#  'text_feature_282',
#  'text_feature_283',
#  'text_feature_284',
#  'text_feature_285',
#  'text_feature_286',
#  'text_feature_287',
#  'text_feature_288',
#  'text_feature_289',
#  'text_feature_290',
#  'text_feature_291',
#  'text_feature_292',
#  'text_feature_293',
#  'text_feature_294',
#  'text_feature_295',
#  'text_feature_296',
#  'text_feature_297',
#  'text_feature_298',
#  'text_feature_299',
#  'text_feature_300',
#  'Number of Words',
#  'Number of Unique Words',
#  'Lexical Diversity']

# %%
from sklearn.preprocessing import MinMaxScaler


X_scaled = MinMaxScaler().fit_transform(X)

# %%
X_scaled.shape
# Out:
# (18846, 303)

# %%
X_tensor = tr.from_numpy(X_scaled)

# %%
X_tensor.shape
# Out:
# torch.Size([18846, 303])

# %%
from kmeans import KMeans

# %%
# random state for reproducibility
model = KMeans(n_clusters=20, random_state=42)
model.fit(X_tensor)
# Out:
# d:\Miniconda\envs\ATiML_Project\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.metrics.cluster import contingency_matrix
from scipy.optimize import linear_sum_assignment

# %%
# find best match between clusters and classes
y = model.decision(X_tensor)
C = contingency_matrix(ytrue, y) # def contingency_matrix(labels_true: ArrayLike,labels_pred: ArrayLike)
_, best_match = linear_sum_assignment(-C.T)
y = tr.tensor([best_match[i] for i in y])

# %%
y
# Out:
# tensor([10,  6, 17,  ...,  3,  0, 16])

# %%
y.shape
# Out:
# torch.Size([18846])

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
# compute a PCA embedding for visualization
pca = PCA(n_components=2).fit(X_tensor)
Z = pca.transform(X_tensor)

# Define the colormap
cmap = plt.get_cmap('tab10')

plt.title('wine clustering --- facecolor: clusters, edgecolor: classes')
plt.scatter(Z[:,0], Z[:,1], facecolor=cmap(2*y.numpy() + 1), edgecolor= cmap(2*ytrue.numpy()), alpha=.5)
plt.gca().set_aspect('equal')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
logits=model(X_tensor)

# %%
logits
# Out:
# tensor([0.0782, 0.0584, 0.0220,  ..., 0.0759, 0.0593, 0.0108],
#        dtype=torch.float64)

# %%
logits.shape
# Out:
# torch.Size([18846])

# %%
model
# Out:
# KMeans()

# %%
from neon import NeuralizedKMeans, neon

# %%
neon_model=NeuralizedKMeans(model)

# %%
neon_model
# Out:
# NeuralizedKMeans(
#   (kmeans): KMeans()
# )

# %%
# check if all outputs are exactly the same with the neuralized model
assert tr.isclose(logits, neon_model(X_tensor)).all(), "Predictions are not equal!"

# %%
R = neon(neon_model, X_tensor, beta=1)

# %%
R.shape
# Out:
# torch.Size([18846, 303])

# %%
from utils import *

# %%
type(feature_names_)
# Out:
# list

# %%
I = tr.nonzero(y != ytrue)[:3,0]
for i in I:
    logit = logits[i]
    prob = 1 / (1 + tr.exp(-logit))

    print('data point %d'%i)
    print('  cluster assignment: %d (probability %.2f)'%(y[i],prob))
    print('  true class        : %d'%ytrue[i])
    print('  sum(R) / logit    : %.4f / %.4f'%(sum(R[i]), logit))
    plot_explanation(X_tensor[i], R[i], feature_names_, vlim=abs(R[I]).max()*1.1)
    plt.show()
    print('-'*80)
# Out:
# data point 1
#   cluster assignment: 6 (probability 0.51)
#   true class        : 3
#   sum(R) / logit    : 0.0584 / 0.0584
# --------------------------------------------------------------------------------
# data point 4
#   cluster assignment: 12 (probability 0.51)
#   true class        : 4
#   sum(R) / logit    : 0.0219 / 0.0219
# --------------------------------------------------------------------------------
# data point 6
#   cluster assignment: 2 (probability 0.55)
#   true class        : 4
#   sum(R) / logit    : 0.1888 / 0.1888
# --------------------------------------------------------------------------------

# %%
I = tr.nonzero(y == ytrue)[:3,0]
for i in I:
    logit = logits[i]
    prob = 1 / (1 + tr.exp(-logit))

    print('data point %d'%i)
    print('  cluster assignment: %d (probability %.2f)'%(y[i],prob))
    print('  true class        : %d'%ytrue[i])
    print('  sum(R) / logit    : %.4f / %.4f'%(sum(R[i]), logit))
    plot_explanation(X_tensor[i], R[i], feature_names_, vlim=abs(R[I]).max()*1.1)
    plt.show()
    print('-'*80)
# Out:
# data point 0
#   cluster assignment: 10 (probability 0.52)
#   true class        : 10
#   sum(R) / logit    : 0.0782 / 0.0782
# --------------------------------------------------------------------------------
# data point 2
#   cluster assignment: 17 (probability 0.51)
#   true class        : 17
#   sum(R) / logit    : 0.0220 / 0.0220
# --------------------------------------------------------------------------------
# data point 3
#   cluster assignment: 3 (probability 0.55)
#   true class        : 3
#   sum(R) / logit    : 0.1997 / 0.1997
# --------------------------------------------------------------------------------
